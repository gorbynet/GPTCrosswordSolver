# %%
import pandas as pd
import os

# %%
open_ai_df = pd.read_csv('pairs.txt', sep='\t', names=['prompt', 'completion'] )
open_ai_df.head()
# Out:
#                                               prompt     completion
# 0  Giving affection, having a close relationship ...  HAND IN GLOVE
# 1             Feature about American’s restraint (5)          CHAIN
# 2                 Fruit from two different trees (9)      PINEAPPLE
# 3  Bank bordering a street is better for consumer...        TASTIER
# 4       Dog that is following Antarctic explorer (7)        SCOTTIE

# %%
open_ai_df.to_json(os.path.join('pairs.jsonl'), orient='records', lines=True)

# %%
# !openai tools fine_tunes.prepare_data -f pairs.jsonl -q
# Out:
# Analyzing...
#
# - Your file contains 44313 prompt-completion pairs
# ...

# %%
import openai
openai.organization = "org-vWwpkH2lbgxgnK3SRVTRJcAv"
# openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_key_path = os.path.join('secrets', 'api_key.txt')
openai.Model.list()
# Out:
# <OpenAIObject list at 0x1ed6ea6bd70> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...
